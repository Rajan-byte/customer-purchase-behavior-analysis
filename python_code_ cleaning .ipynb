# %%
import pandas as pd
from io import StringIO
data = """customer_id,gender,age,city,signup_date,last_purchase_date,total_orders,total_spend,avg_order_value,preferred_channel,is_active
CUST001,Male,34,New York,2022-01-15,2023-03-10,12,2400,200,Online,Yes
CUST002,Female,28,Los Angeles,2022-03-20,2022-11-05,5,750,150,In-Store,No
CUST003,,45,Chicago,2021-07-10,2023-02-25,20,4200,210,Online,Yes
CUST004,Female,NaN,Houston,2022-05-05,2022-08-15,3,300,100,Online,No
CUST005,Male,39,Phoenix,2021-11-30,2023-03-01,18,3600,200,In-Store,Yes
CUST006,Female,22,New York,2023-01-10,2023-02-05,2,180,90,Online,Yes
CUST007,Male,NaN,Chicago,2022-02-18,,7,1400,200,In-Store,No
CUST008,Female,31,Los Angeles,2021-09-25,2023-01-12,15,3000,200,Online,Yes
CUST009,Male,52,,2020-04-15,2022-12-30,25,5000,200,In-Store,Yes
CUST010,Female,27,New York,2022-06-08,2022-07-20,1,100,100,Online,No
CUST011,Male,36,Chicago,2021-03-03,2023-03-18,22,4400,200,Online,Yes
CUST012,Female,41,Houston,2020-10-10,2021-12-01,10,1800,180,In-Store,No
CUST013,Male,29,Los Angeles,2022-08-15,2023-02-10,6,900,150,Online,Yes
CUST014,Female,,Phoenix,2021-12-05,2023-01-28,14,2800,200,In-Store,Yes
CUST015,Male,48,New York,2020-02-20,2022-09-30,19,3800,200,Online,No 
"""
df= pd.read_csv(StringIO(data))
df
# Out:
#    customer_id  gender   age         city signup_date last_purchase_date  \
# 0      CUST001    Male  34.0     New York  2022-01-15         2023-03-10
# 1      CUST002  Female  28.0  Los Angeles  2022-03-20         2022-11-05
# 2      CUST003     NaN  45.0      Chicago  2021-07-10         2023-02-25
# 3      CUST004  Female   NaN      Houston  2022-05-05         2022-08-15
# 4      CUST005    Male  39.0      Phoenix  2021-11-30         2023-03-01
# 5      CUST006  Female  22.0     New York  2023-01-10         2023-02-05
# 6      CUST007    Male   NaN      Chicago  2022-02-18                NaN
# 7      CUST008  Female  31.0  Los Angeles  2021-09-25         2023-01-12
# 8      CUST009    Male  52.0          NaN  2020-04-15         2022-12-30
# 9      CUST010  Female  27.0     New York  2022-06-08         2022-07-20
# 10     CUST011    Male  36.0      Chicago  2021-03-03         2023-03-18
# 11     CUST012  Female  41.0      Houston  2020-10-10         2021-12-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         15 non-null     object
#  1   gender              14 non-null     object
#  2   age                 12 non-null     float64
#  3   city                14 non-null     object
#  4   signup_date         15 non-null     object
#  5   last_purchase_date  14 non-null     object
#  6   total_orders        15 non-null     int64
#  7   total_spend         15 non-null     int64
#  8   avg_order_value     15 non-null     int64
#  9   preferred_channel   15 non-null     object
#  10  is_active           15 non-null     object
# dtypes: float64(1), int64(3), object(7)
# memory usage: 1.4+ KB

# %%
df.isnull().sum()
# Out:
# customer_id           0
# gender                1
# age                   3
# city                  1
# signup_date           0
# last_purchase_date    1
# total_orders          0
# total_spend           0
# avg_order_value       0
# preferred_channel     0
# is_active             0
# dtype: int64

# %%
df['is_active'] = df['is_active'].str.strip()

# %%
df['is_active'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df.fillna(0, inplace = True)

# %%
df
# Out:
#    customer_id  gender   age         city signup_date last_purchase_date  \
# 0      CUST001    Male  34.0     New York  2022-01-15         2023-03-10
# 1      CUST002  Female  28.0  Los Angeles  2022-03-20         2022-11-05
# 2      CUST003       0  45.0      Chicago  2021-07-10         2023-02-25
# 3      CUST004  Female   0.0      Houston  2022-05-05         2022-08-15
# 4      CUST005    Male  39.0      Phoenix  2021-11-30         2023-03-01
# 5      CUST006  Female  22.0     New York  2023-01-10         2023-02-05
# 6      CUST007    Male   0.0      Chicago  2022-02-18                  0
# 7      CUST008  Female  31.0  Los Angeles  2021-09-25         2023-01-12
# 8      CUST009    Male  52.0            0  2020-04-15         2022-12-30
# 9      CUST010  Female  27.0     New York  2022-06-08         2022-07-20
# 10     CUST011    Male  36.0      Chicago  2021-03-03         2023-03-18
# 11     CUST012  Female  41.0      Houston  2020-10-10         2021-12-01
# ...

# %%
df['age'] = df['age'].astype(int)

# %%
df['signup_date'] = pd.to_datetime(df['signup_date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         15 non-null     object
#  1   gender              15 non-null     object
#  2   age                 15 non-null     int32
#  3   city                15 non-null     object
#  4   signup_date         15 non-null     datetime64[ns]
#  5   last_purchase_date  14 non-null     datetime64[ns]
#  6   total_orders        15 non-null     int64
#  7   total_spend         15 non-null     int64
#  8   avg_order_value     15 non-null     int64
#  9   preferred_channel   15 non-null     object
#  10  is_active           15 non-null     object
# dtypes: datetime64[ns](2), int32(1), int64(3), object(5)
# memory usage: 1.4+ KB

# %%
df['last_purchase_date'] = df['last_purchase_date'].replace(0,'UNKNOWN')

# %%
df['last_purchase_date'] = pd.to_datetime(df['last_purchase_date'],errors ='coerce')

# %%
df
# Out:
#    customer_id  gender  age         city signup_date last_purchase_date  \
# 0      CUST001    Male   34     New York  2022-01-15         2023-03-10
# 1      CUST002  Female   28  Los Angeles  2022-03-20         2022-11-05
# 2      CUST003       0   45      Chicago  2021-07-10         2023-02-25
# 3      CUST004  Female    0      Houston  2022-05-05         2022-08-15
# 4      CUST005    Male   39      Phoenix  2021-11-30         2023-03-01
# 5      CUST006  Female   22     New York  2023-01-10         2023-02-05
# 6      CUST007    Male    0      Chicago  2022-02-18                NaT
# 7      CUST008  Female   31  Los Angeles  2021-09-25         2023-01-12
# 8      CUST009    Male   52            0  2020-04-15         2022-12-30
# 9      CUST010  Female   27     New York  2022-06-08         2022-07-20
# 10     CUST011    Male   36      Chicago  2021-03-03         2023-03-18
# 11     CUST012  Female   41      Houston  2020-10-10         2021-12-01
# ...

# %%
df[['age','gender','city']] = df[['age','gender','city']].replace(0,'UNKNOWN')

# %%
df
# Out:
#    customer_id   gender      age         city signup_date last_purchase_date  \
# 0      CUST001     Male       34     New York  2022-01-15         2023-03-10
# 1      CUST002   Female       28  Los Angeles  2022-03-20         2022-11-05
# 2      CUST003  UNKNOWN       45      Chicago  2021-07-10         2023-02-25
# 3      CUST004   Female  UNKNOWN      Houston  2022-05-05         2022-08-15
# 4      CUST005     Male       39      Phoenix  2021-11-30         2023-03-01
# 5      CUST006   Female       22     New York  2023-01-10         2023-02-05
# 6      CUST007     Male  UNKNOWN      Chicago  2022-02-18                NaT
# 7      CUST008   Female       31  Los Angeles  2021-09-25         2023-01-12
# 8      CUST009     Male       52      UNKNOWN  2020-04-15         2022-12-30
# 9      CUST010   Female       27     New York  2022-06-08         2022-07-20
# 10     CUST011     Male       36      Chicago  2021-03-03         2023-03-18
# ...

# %%
df.describe()
# Out:
#                signup_date             last_purchase_date  total_orders  \
# count                   15                             14     15.000000
# mean   2021-10-01 17:36:00  2022-11-27 15:25:42.857142784     11.933333
# min    2020-02-20 00:00:00            2021-12-01 00:00:00      1.000000
# 25%    2021-05-06 12:00:00            2022-10-09 00:00:00      5.500000
# 50%    2021-12-05 00:00:00            2023-01-20 00:00:00     12.000000
# 75%    2022-04-12 00:00:00            2023-02-21 06:00:00     18.500000
# max    2023-01-10 00:00:00            2023-03-18 00:00:00     25.000000
# std                    NaN                            NaN      7.777868
#
#        total_spend  avg_order_value
# count    15.000000        15.000000
# mean   2308.666667       172.000000
# min     100.000000        90.000000
# 25%     825.000000       150.000000
# 50%    2400.000000       200.000000
# 75%    3700.000000       200.000000
# max    5000.000000       210.000000
# ...

# %%
import numpy as np
df['age'] = df['age'].replace('UNKNOWN', np.nan)
# Out:
# C:\Users\13309\AppData\Local\Temp\ipykernel_39928\3136833775.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['age'] = df['age'].replace('UNKNOWN', np.nan)

# %%
df
# Out:
#    customer_id   gender   age         city signup_date last_purchase_date  \
# 0      CUST001     Male  34.0     New York  2022-01-15         2023-03-10
# 1      CUST002   Female  28.0  Los Angeles  2022-03-20         2022-11-05
# 2      CUST003  UNKNOWN  45.0      Chicago  2021-07-10         2023-02-25
# 3      CUST004   Female   NaN      Houston  2022-05-05         2022-08-15
# 4      CUST005     Male  39.0      Phoenix  2021-11-30         2023-03-01
# 5      CUST006   Female  22.0     New York  2023-01-10         2023-02-05
# 6      CUST007     Male   NaN      Chicago  2022-02-18                NaT
# 7      CUST008   Female  31.0  Los Angeles  2021-09-25         2023-01-12
# 8      CUST009     Male  52.0      UNKNOWN  2020-04-15         2022-12-30
# 9      CUST010   Female  27.0     New York  2022-06-08         2022-07-20
# 10     CUST011     Male  36.0      Chicago  2021-03-03         2023-03-18
# 11     CUST012   Female  41.0      Houston  2020-10-10         2021-12-01
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   customer_id         15 non-null     object
#  1   gender              15 non-null     object
#  2   age                 12 non-null     float64
#  3   city                15 non-null     object
#  4   signup_date         15 non-null     datetime64[ns]
#  5   last_purchase_date  14 non-null     datetime64[ns]
#  6   total_orders        15 non-null     int64
#  7   total_spend         15 non-null     int64
#  8   avg_order_value     15 non-null     int64
#  9   preferred_channel   15 non-null     object
#  10  is_active           15 non-null     object
# dtypes: datetime64[ns](2), float64(1), int64(3), object(5)
# memory usage: 1.4+ KB

# %%
df['customer_tenure_days'] = (df['last_purchase_date'] - df['signup_date']).dt.days

# %%
df
# Out:
#    customer_id   gender   age         city signup_date last_purchase_date  \
# 0      CUST001     Male  34.0     New York  2022-01-15         2023-03-10
# 1      CUST002   Female  28.0  Los Angeles  2022-03-20         2022-11-05
# 2      CUST003  UNKNOWN  45.0      Chicago  2021-07-10         2023-02-25
# 3      CUST004   Female   NaN      Houston  2022-05-05         2022-08-15
# 4      CUST005     Male  39.0      Phoenix  2021-11-30         2023-03-01
# 5      CUST006   Female  22.0     New York  2023-01-10         2023-02-05
# 6      CUST007     Male   NaN      Chicago  2022-02-18                NaT
# 7      CUST008   Female  31.0  Los Angeles  2021-09-25         2023-01-12
# 8      CUST009     Male  52.0      UNKNOWN  2020-04-15         2022-12-30
# 9      CUST010   Female  27.0     New York  2022-06-08         2022-07-20
# 10     CUST011     Male  36.0      Chicago  2021-03-03         2023-03-18
# 11     CUST012   Female  41.0      Houston  2020-10-10         2021-12-01
# ...

# %%
reference_date = df['last_purchase_date'].max()
df['recency_days'] = (reference_date - df['last_purchase_date']).dt.days

# %%
df['recency_days'] = df['recency_days'].fillna(df['recency_days'].max())

# %%
df
# Out:
#    customer_id   gender   age         city signup_date last_purchase_date  \
# 0      CUST001     Male  34.0     New York  2022-01-15         2023-03-10
# 1      CUST002   Female  28.0  Los Angeles  2022-03-20         2022-11-05
# 2      CUST003  UNKNOWN  45.0      Chicago  2021-07-10         2023-02-25
# 3      CUST004   Female   NaN      Houston  2022-05-05         2022-08-15
# 4      CUST005     Male  39.0      Phoenix  2021-11-30         2023-03-01
# 5      CUST006   Female  22.0     New York  2023-01-10         2023-02-05
# 6      CUST007     Male   NaN      Chicago  2022-02-18                NaT
# 7      CUST008   Female  31.0  Los Angeles  2021-09-25         2023-01-12
# 8      CUST009     Male  52.0      UNKNOWN  2020-04-15         2022-12-30
# 9      CUST010   Female  27.0     New York  2022-06-08         2022-07-20
# 10     CUST011     Male  36.0      Chicago  2021-03-03         2023-03-18
# 11     CUST012   Female  41.0      Houston  2020-10-10         2021-12-01
# ...

# %%
df['signup_date'] = pd.to_datetime(df['signup_date'])
df['tenure_days'] = (reference_date - df['signup_date']).dt.days

# %%
df['orders_per_year'] = df['total_orders'] / (df['tenure_days'] / 365)

# %%
df
# Out:
#    customer_id   gender   age         city signup_date last_purchase_date  \
# 0      CUST001     Male  34.0     New York  2022-01-15         2023-03-10
# 1      CUST002   Female  28.0  Los Angeles  2022-03-20         2022-11-05
# 2      CUST003  UNKNOWN  45.0      Chicago  2021-07-10         2023-02-25
# 3      CUST004   Female   NaN      Houston  2022-05-05         2022-08-15
# 4      CUST005     Male  39.0      Phoenix  2021-11-30         2023-03-01
# 5      CUST006   Female  22.0     New York  2023-01-10         2023-02-05
# 6      CUST007     Male   NaN      Chicago  2022-02-18                NaT
# 7      CUST008   Female  31.0  Los Angeles  2021-09-25         2023-01-12
# 8      CUST009     Male  52.0      UNKNOWN  2020-04-15         2022-12-30
# 9      CUST010   Female  27.0     New York  2022-06-08         2022-07-20
# 10     CUST011     Male  36.0      Chicago  2021-03-03         2023-03-18
# 11     CUST012   Female  41.0      Houston  2020-10-10         2021-12-01
# ...

# %%
df['customer_tenure_days'] = df['customer_tenure_days'].replace('Nan', 0)

# %%
df.groupby('is_active')[[
    'total_orders',
    'total_spend',
    'avg_order_value',
    'recency_days',
    'orders_per_year'
]].mean().round(2)
# Out:
#            total_orders  total_spend  avg_order_value  recency_days  \
# is_active
# No                 7.50      1358.33           155.00        288.67
# Yes               14.89      2942.22           183.33         35.00
#
#            orders_per_year
# is_active
# No                    4.43
# Yes                  10.83

# %%
df.groupby('recency_days')['total_spend'].mean()
# Out:
# recency_days
# 0.0      4400.0
# 8.0      2400.0
# 17.0     3600.0
# 21.0     4200.0
# 36.0      900.0
# 41.0      180.0
# 49.0     2800.0
# 65.0     3000.0
# 78.0     5000.0
# 133.0     750.0
# 169.0    3800.0
# 215.0     300.0
# 241.0     100.0
# 472.0    1800.0
# 502.0    1400.0
# Name: total_spend, dtype: float64

# %%
df.groupby('preferred_channel')['total_spend'].mean().round(2)
# Out:
# preferred_channel
# In-Store    2558.33
# Online      2142.22
# Name: total_spend, dtype: float64

# %%
df.groupby('preferred_channel')['orders_per_year'].mean()
# Out:
# preferred_channel
# In-Store    8.165907
# Online      8.338999
# Name: orders_per_year, dtype: float64

# %%
plt.figure()
df.boxplot(column='recency_days', by='is_active')
plt.xlabel('Is Active')
plt.ylabel('Recency Days')
plt.title('Recency by Customer Activity')
plt.suptitle('')
plt.show()

# %%
df['churn_risk'] = (
    (df['recency_days'] > 120) |
    (df['orders_per_year'] < 4)
)

df[['customer_id', 'recency_days', 'orders_per_year', 'churn_risk']]
# Out:
#    customer_id  recency_days  orders_per_year  churn_risk
# 0      CUST001           8.0        10.257611       False
# 1      CUST002         133.0         5.027548        True
# 2      CUST003          21.0        11.850649       False
# 3      CUST004         215.0         3.454259        True
# 4      CUST005          17.0        13.890063       False
# 5      CUST006          41.0        10.895522       False
# 6      CUST007         502.0         6.501272        True
# 7      CUST008          65.0        10.157699       False
# 8      CUST009          78.0         8.552015       False
# 9      CUST010         241.0         1.289753        True
# 10     CUST011           0.0        10.778523       False
# 11     CUST012         472.0         4.105737        True
# 12     CUST013          36.0        10.186047       False
# 13     CUST014          49.0        10.918803       False
# 14     CUST015         169.0         6.180927        True

# %%
df['churn_risk'].value_counts()
# Out:
# churn_risk
# False    9
# True     6
# Name: count, dtype: int64

# %%
pd.crosstab(df['is_active'], df['churn_risk'])
# Out:
# churn_risk  False  True
# is_active
# No              0      6
# Yes             9      0

# %%
features = [
    'recency_days',
    'orders_per_year',
    'customer_tenure_days',
    'total_orders',
    'total_spend'
]

X = df[features]
y = df['churn_risk']

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[73], line 4
#       1 from sklearn.linear_model import LogisticRegression
#       3 model = LogisticRegression(max_iter=1000)
# ----> 4 model.fit(X_train, y_train)
#
# File ~\OneDrive\New folder\Lib\site-packages\sklearn\base.py:1473, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1466     estimator._validate_params()
#    1468 with config_context(
#    1469     skip_parameter_validation=(
#    1470         prefer_skip_nested_validation or global_skip_validation
#    1471     )
#    1472 ):
# -> 1473     return fit_method(estimator, *args, **kwargs)
#
# File ~\OneDrive\New folder\Lib\site-packages\sklearn\linear_model\_logistic.py:1223, in LogisticRegression.fit(self, X, y, sample_weight)
#    1220 else:
#    1221     _dtype = [np.float64, np.float32]
# ...
